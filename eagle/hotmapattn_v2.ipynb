# %%
import torch
import numpy as np
attn = torch.load("/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/draft1.pt").to('cpu')
print(attn.shape)
# Out:
# torch.Size([1, 32, 60, 222])

# %%
def extract_zero(attn_weights:torch.Tensor):
    iszero = attn_weights < 0.01
    zeroindex = torch.all(iszero,dim=1)
    print(zeroindex.shape)
    # for i in np.array(zeroindex).tolist()[0]:
    #     print(i)
    print(zeroindex.sum(dim=-1))
    
extract_zero(attn)
# Out:
# torch.Size([1, 60, 222])
# tensor([[100,  99, 124, 113, 123, 122, 117, 118, 106, 107, 117, 116, 110, 122,
#          119, 113, 125,  99,  96,  90, 102,  95, 100, 104, 115,  95,  97,  99,
#           98,  98, 110, 118,  94,  74,  86,  80,  98, 111, 109,  93, 111,  98,
#           97,  73,  84,  88,  84,  84,  78,  92,  92,  88, 102, 102, 108, 110,
#          117, 114, 115, 115]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Create a custom colormap
colors = ["#ffffcc", "#a1dab4", "#41b6c4", "#2c7fb8", "#253494"]  # Define custom colors
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", colors)  # Create custom colormap

def count_importance(attn_weights: torch.Tensor,selecttoken=None):
    imps = []

    for i in range(selecttoken,selecttoken+1):  # 默认处理第一个 head
        head_attn = attn_weights[ :, :, i, :].reshape(-1, attn_weights.shape[3])  # shape: (N, seq_len)

        # 布尔张量：大于0.05的元素
        aboveattn = head_attn  # shape: (N, seq_len)
        print(aboveattn.shape)

        # 找出重要列（即 >0.05 占比超过0.1 的列）
        important_indices = (aboveattn > 0.05).nonzero(as_tuple=True)[0]  # shape: (num_important_cols,)
        print(important_indices)

        print(f'num_important_columns: {important_indices}')

        imps.append(len(important_indices))

    print(f"Average number of important columns: {sum(imps) / len(imps):.2f}")


def plot_attention(attn_weights, head):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    head_attn = attn_weights[0, head]  # 取 batch=0, 指定头
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    plt.colorbar()
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

def plot_attention_all_head(attn_weights:torch.Tensor,selecttoken):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    # head_attn = attn_weights.reshape(-1,attn_weights.shape[3])  # 取 batch=0, 指定头
    head_attn = attn_weights[:,selecttoken,:].reshape(-1,attn_weights.shape[2])  # 取 batch=0, 指定头
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    # plt.colorbar()
    plt.xticks(range(0,head_attn.shape[0],32))
    plt.savefig('hotmapattn.pdf')
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

    
def get_pipeline(startlinear,selecttoken=7):
    originarea = (startlinear+1)* 32

    origin_attn = []
    for i in range(originarea,originarea+32):
        origin_attn .append( torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/real{i}.pt").to('cpu') )
    origin_attn = torch.cat(origin_attn,dim=0)
    # print(origin_attn.shape)


    draft_attn=torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/draft{startlinear}.pt").to('cpu')
    # draft_attn = torch.stack(draft_attn)
    # print(len(draft_attn),draft_attn[0].shape)
    
    print('[',originarea,'->',originarea+32,');[',startlinear,');',end=' ')
    print('length:',origin_attn.shape[-1],end=' ')

    draft_attn=draft_attn.sum(dim=1)
    origin_attn=origin_attn.sum(dim=1)

    plot_attention_all_head(torch.cat([draft_attn,origin_attn],dim=0),selecttoken)
    print('basemodel')
    count_importance(origin_attn,selecttoken)
    print('draft')
    count_importance(draft_attn,selecttoken)

get_pipeline(30,15)
# Out:
# [ 992 -> 1024 );[ 30 ); length: 383
# basemodel
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 82
#      79     print('draft')
#      80     count_importance(draft_attn,selecttoken)
# ---> 82 get_pipeline(30,15)
#
# Cell In[13], line 78, in get_pipeline(startlinear, selecttoken)
#      76 plot_attention_all_head(torch.cat([draft_attn,origin_attn],dim=0),selecttoken)
#      77 print('basemodel')
# ---> 78 count_importance(origin_attn,selecttoken)
#      79 print('draft')
#      80 count_importance(draft_attn,selecttoken)
#
# Cell In[13], line 13, in count_importance(attn_weights, selecttoken)
#      10 imps = []
#      12 for i in range(selecttoken,selecttoken+1):  # 默认处理第一个 head
# ---> 13     head_attn = attn_weights[ :, :, i, :].reshape(-1, attn_weights.shape[3])  # shape: (N, seq_len)
#      15     # 布尔张量：大于0.05的元素
#      16     aboveattn = head_attn  # shape: (N, seq_len)
#
# IndexError: too many indices for tensor of dimension 3

# %%
import torch
import numpy as np
attn = torch.load("/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/draft0.pt").to('cpu')
print(attn.shape)

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Create a custom colormap
colors = ["#ffffcc", "#a1dab4", "#41b6c4", "#2c7fb8", "#253494"]  # Define custom colors
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", colors)  # Create custom colormap

def plot_attention(attn_weights, head):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    head_attn = attn_weights[0, head]  # 取 batch=0, 指定头
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    plt.colorbar()
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

def plot_attention_all_head(attn_weights:torch.Tensor):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    # head_attn = attn_weights.reshape(-1,attn_weights.shape[3])  # 取 batch=0, 指定头
    # head_attn = attn_weights
    head_attn = attn_weights.permute(0,2,1,3).reshape(-1,attn_weights.shape[3])
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    # plt.colorbar()
    plt.xticks(range(0,head_attn.shape[0],32))
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

# 示例：可视化 Draft Model 第 3 层、第 5 头
# plot_attention(
#     attn, 
#     head=5,
# )

def count_importance(attn_weights: torch.Tensor):
    imps = []

    for i in range(60):  # 默认处理第一个 head
        head_attn = attn_weights[ :, :, i, :].reshape(-1, attn_weights.shape[3])  # shape: (N, seq_len)

        # 布尔张量：大于0.05的元素
        aboveattn = head_attn > 0.05  # shape: (N, seq_len)

        # 每列中 >0.05 的占比
        abovecount = aboveattn.to(dtype=torch.float64).mean(dim=0)  # shape: (seq_len,)

        # 找出重要列（即 >0.05 占比超过0.1 的列）
        important_indices = (abovecount > 0.1).nonzero(as_tuple=True)[0]  # shape: (num_important_cols,)

        # 分子：这些重要列中，>0.05 的元素数量
        important_column_mask = aboveattn[:, important_indices]
        num_important_above = important_column_mask.sum().item()

        # 分母：所有 >0.05 的元素数量
        total_above = aboveattn.sum().item()

        # 比例计算
        if total_above > 0:
            importance_ratio = num_important_above / total_above
        else:
            importance_ratio = 0.0

        print(f'importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): {importance_ratio:.4f}')
        print(f'num_important_columns: {important_indices}')

        imps.append(len(important_indices))

    print(f"Average number of important columns: {sum(imps) / len(imps):.2f}")


# plot_attention_all_head(attn)

count_importance(attn)
# Out:
# torch.Size([1, 32, 60, 218])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7250
# num_important_columns: tensor([  0,   2, 128, 142, 143, 145, 152, 158])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8148
# num_important_columns: tensor([  0,   2,  59, 128, 142, 143, 152, 154, 158, 159])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7748
# num_important_columns: tensor([  0,   2, 128, 142, 143, 152, 154, 158, 159, 160])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7917
# num_important_columns: tensor([  0,   2, 128, 152, 158, 159, 160, 161])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7607
# num_important_columns: tensor([  0,   2, 126, 128, 158, 159, 160, 161, 162])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7734
# num_important_columns: tensor([  0,   2, 128, 142, 158, 159, 160, 161, 162, 163])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6519
# num_important_columns: tensor([  0,   2,  18, 128, 159, 160, 161, 163, 164])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6894
# num_important_columns: tensor([  0,   2, 128, 159, 160, 161, 162, 163, 164, 165])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6617
# num_important_columns: tensor([  0,   2,  19, 128, 142, 159, 161, 164, 165, 166])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6967
# num_important_columns: tensor([  0,   2, 128, 142, 143, 152, 154, 158, 159, 167])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5926
# num_important_columns: tensor([  0,   2, 128, 142, 154, 166, 168])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6471
# num_important_columns: tensor([  0,   2, 128, 142, 143, 152, 168, 169])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6807
# num_important_columns: tensor([  0,   2, 128, 142, 143, 154, 168, 169, 170])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6800
# num_important_columns: tensor([  0,   2, 128, 142, 154, 168, 169, 170, 171])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6161
# num_important_columns: tensor([  0, 142, 163, 166, 168, 169, 170, 172])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5172
# num_important_columns: tensor([  0, 128, 143, 168, 169, 170, 173])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7286
# num_important_columns: tensor([  0,   2, 143, 152, 154, 160, 162, 163, 164, 168, 169, 170, 171, 172,
#         174])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7589
# num_important_columns: tensor([  0,   2, 128, 142, 143, 152, 160, 161, 163, 164, 169, 170, 171, 172,
#         174, 175])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5556
# num_important_columns: tensor([  0,   2, 128, 146, 163, 169, 170, 176])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5872
# num_important_columns: tensor([  0,   2, 128, 165, 168, 169, 177])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5221
# num_important_columns: tensor([  0, 126, 142, 152, 168, 170, 171, 176, 178])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6286
# num_important_columns: tensor([  0,   2, 128, 169, 170, 179])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5870
# num_important_columns: tensor([  0,   2, 128, 179, 180])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6952
# num_important_columns: tensor([  0,   2, 128, 142, 179, 180, 181])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5882
# num_important_columns: tensor([  0,   2,  19, 128, 182])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7714
# num_important_columns: tensor([  0,   2, 128, 179, 180, 181, 182, 183])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7100
# num_important_columns: tensor([  0,   2, 128, 180, 181, 182, 183, 184])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6695
# num_important_columns: tensor([  0,   2,  19,  55, 128, 182, 184, 185])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7766
# num_important_columns: tensor([  0, 128, 180, 181, 183, 184, 185, 186])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6535
# num_important_columns: tensor([  0,   2, 128, 180, 183, 184, 186, 187])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6017
# num_important_columns: tensor([  0,   2, 128, 184, 185, 187, 188])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7179
# num_important_columns: tensor([  0,   2, 128, 179, 180, 181, 182, 183, 184, 186, 189])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6075
# num_important_columns: tensor([  0,   2, 128, 180, 181, 184, 186, 189, 190])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5789
# num_important_columns: tensor([  0,   2, 128, 142, 171, 182, 184, 191])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4479
# num_important_columns: tensor([  0, 128, 185, 192])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4902
# num_important_columns: tensor([  0, 128, 183, 184, 185, 193])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5268
# num_important_columns: tensor([  0,   2, 128, 143, 146, 154, 194])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6327
# num_important_columns: tensor([  0, 128, 142, 143, 149, 154, 192, 195])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4038
# num_important_columns: tensor([  0, 142, 181, 189, 196])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.3889
# num_important_columns: tensor([  0, 128, 197])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5658
# num_important_columns: tensor([  0,   2, 128, 152, 198])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6264
# num_important_columns: tensor([  0,   2, 128, 184, 192, 198, 199])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4632
# num_important_columns: tensor([  0, 128, 184, 199, 200])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4559
# num_important_columns: tensor([  0, 199, 200, 201])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4607
# num_important_columns: tensor([  0, 142, 152, 154, 198, 202])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4486
# num_important_columns: tensor([  0,   2, 142, 198, 199, 203])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5342
# num_important_columns: tensor([  0, 198, 202, 204])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5806
# num_important_columns: tensor([  0, 128, 199, 200, 201, 205])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4211
# num_important_columns: tensor([  0, 128, 198, 202, 204, 206])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.3182
# num_important_columns: tensor([  0, 199, 200, 205, 207])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6522
# num_important_columns: tensor([  0,   2,  19, 128, 142, 154, 208])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5814
# num_important_columns: tensor([  0, 128, 142, 145, 154, 209])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5243
# num_important_columns: tensor([  0, 145, 146, 158, 167, 168, 188, 198, 210])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4370
# num_important_columns: tensor([  0, 134, 135, 136, 142, 169, 211])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5966
# num_important_columns: tensor([  0,  55,  59, 145, 154, 158, 168, 188, 198, 212])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.5743
# num_important_columns: tensor([  0, 142, 143, 152, 154, 200, 213])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4184
# num_important_columns: tensor([  0, 128, 161, 214])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.3735
# num_important_columns: tensor([  0, 134, 135, 167, 215])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.4455
# num_important_columns: tensor([  0, 140, 143, 144, 146, 152, 160, 216])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6694
# num_important_columns: tensor([  0, 140, 141, 142, 143, 158, 159, 160, 161, 162, 164, 166, 167, 170,
#         217])
# Average number of important columns: 7.67

# %%
import torch
import numpy as np
attns = []
for i in range(32,64):
    attns.append(torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/real{i}.pt").to('cpu'))
attns = torch.stack(attns)
print(attns.shape)

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Create a custom colormap
colors = ["#ffffcc", "#a1dab4", "#41b6c4", "#2c7fb8", "#253494"]  # Define custom colors
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", colors)  # Create custom colormap

def plot_attention(attn_weights, head):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    head_attn = attn_weights[0, head]  # 取 batch=0, 指定头
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    plt.colorbar()
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

def plot_attention_all_head(attn_weights:torch.Tensor):
    # attn_weights: 当前层的注意力矩阵 [heads, seq_len, seq_len]
    # head_attn = attn_weights.reshape(-1,attn_weights.shape[3])  # 取 batch=0, 指定头
    # head_attn = attn_weights.permute(0,2,1,3)
    print(attn_weights.shape)
    head_attn = attn_weights[:,:,:,0,:].reshape(-1,attn_weights.shape[4])
    
    plt.figure(figsize=(15, 8))
    plt.imshow(head_attn.T, cmap=custom_cmap, interpolation='nearest')
    # plt.colorbar()
    plt.xticks(range(0,head_attn.shape[0],32))
    plt.show()
    # sns.heatmap(head_attn, cmap="viridis",)# xticklabels=tokens, yticklabels=tokens)
    # plt.show()

# 示例：可视化 Draft Model 第 3 层、第 5 头
# plot_attention(
#     attn, 
#     head=5,
# )

# def count_importance(attn_weights:torch.Tensor):
#     imps=[]
#     for i in range(1):
#         head_attn = attn_weights[:,:,:,i,:].reshape(-1,attn_weights.shape[4])
#         aboveattn = head_attn > 0.05
#         abovecount = aboveattn.to(dtype=torch.float64)
#         # print(abovecount.shape)
#         abovecount = abovecount.mean(dim=0)
#         print(abovecount.shape)
#         impcount = abovecount > 0.1
#         impcount = impcount.sum()
#         print('importance_rate',impcount)
#         imps.append(impcount.item())
#     print(sum(imps)/len(imps))

def count_importance(attn_weights: torch.Tensor):
    imps = []

    for i in range(60):  # 默认处理第一个 head
        head_attn = attn_weights[:, :, :, i, :].reshape(-1, attn_weights.shape[4])  # shape: (N, seq_len)

        # 布尔张量：大于0.05的元素
        aboveattn = head_attn > 0.05  # shape: (N, seq_len)

        # 每列中 >0.05 的占比
        abovecount = aboveattn.to(dtype=torch.float64).mean(dim=0)  # shape: (seq_len,)

        # 找出重要列（即 >0.05 占比超过0.1 的列）
        important_indices = (abovecount > 0.1).nonzero(as_tuple=True)[0]  # shape: (num_important_cols,)

        # 分子：这些重要列中，>0.05 的元素数量
        important_column_mask = aboveattn[:, important_indices]
        num_important_above = important_column_mask.sum().item()

        # 分母：所有 >0.05 的元素数量
        total_above = aboveattn.sum().item()

        # 比例计算
        if total_above > 0:
            importance_ratio = num_important_above / total_above
        else:
            importance_ratio = 0.0

        print(f'importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): {importance_ratio:.4f}')
        print(f'num_important_columns: {important_indices}')

        imps.append(len(important_indices))

    print(f"Average number of important columns: {sum(imps) / len(imps):.2f}")



# plot_attention_all_head(attns)

count_importance(attns)
# Out:
# torch.Size([32, 1, 32, 60, 218])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8184
# num_important_columns: tensor([  0, 142, 157, 158])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7919
# num_important_columns: tensor([  0, 142, 158, 159])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8186
# num_important_columns: tensor([  0, 142, 158, 160])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8068
# num_important_columns: tensor([  0, 157, 158, 161])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8646
# num_important_columns: tensor([  0, 157, 158, 162])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8541
# num_important_columns: tensor([  0, 142, 158, 163])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8293
# num_important_columns: tensor([  0, 142, 158, 164])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8658
# num_important_columns: tensor([  0, 142, 158, 165])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8393
# num_important_columns: tensor([  0, 142, 157, 158, 166])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8457
# num_important_columns: tensor([  0, 142, 157, 158, 167])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8663
# num_important_columns: tensor([  0, 142, 159, 168])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8065
# num_important_columns: tensor([  0, 142, 159, 169])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8702
# num_important_columns: tensor([  0, 142, 159, 170])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8202
# num_important_columns: tensor([  0, 142, 160, 171])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8401
# num_important_columns: tensor([  0, 142, 158, 160, 172])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8552
# num_important_columns: tensor([  0, 142, 158, 173])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8402
# num_important_columns: tensor([  0, 142, 157, 158, 162, 174])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7962
# num_important_columns: tensor([  0, 142, 158, 162, 175])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8788
# num_important_columns: tensor([  0, 142, 158, 163, 176])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8867
# num_important_columns: tensor([  0, 142, 165, 177])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8664
# num_important_columns: tensor([  0, 142, 158, 166, 178])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8552
# num_important_columns: tensor([  0, 142, 173, 179])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8694
# num_important_columns: tensor([  0, 142, 158, 173, 180])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8603
# num_important_columns: tensor([  0, 142, 158, 173, 181])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7708
# num_important_columns: tensor([  0, 142, 173, 182])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8226
# num_important_columns: tensor([  0, 142, 173, 183])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8676
# num_important_columns: tensor([  0, 142, 160, 171, 184])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8818
# num_important_columns: tensor([  0, 142, 160, 171, 185])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8881
# num_important_columns: tensor([  0, 142, 160, 171, 186])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.9128
# num_important_columns: tensor([  0, 142, 160, 171, 187])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8847
# num_important_columns: tensor([  0, 142, 160, 171, 188])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8517
# num_important_columns: tensor([  0, 142, 159, 168, 189])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.9125
# num_important_columns: tensor([  0, 142, 158, 159, 168, 190])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8411
# num_important_columns: tensor([  0, 142, 160, 172, 191])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7807
# num_important_columns: tensor([  0, 142, 174, 192])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8126
# num_important_columns: tensor([  0, 142, 174, 193])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8350
# num_important_columns: tensor([  0, 142, 159, 169, 194])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7772
# num_important_columns: tensor([  0, 142, 175, 195])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8901
# num_important_columns: tensor([  0, 142, 158, 163, 176, 196])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.9149
# num_important_columns: tensor([  0, 142, 165, 177, 197])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7336
# num_important_columns: tensor([  0, 158, 159, 189, 198])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8576
# num_important_columns: tensor([  0, 159, 168, 189, 199])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8417
# num_important_columns: tensor([  0, 142, 172, 191, 200])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8546
# num_important_columns: tensor([  0, 142, 192, 201])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7937
# num_important_columns: tensor([  0, 142, 158, 173, 180, 202])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8619
# num_important_columns: tensor([  0, 142, 169, 194, 203])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7479
# num_important_columns: tensor([  0, 158, 173, 181, 204])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.9035
# num_important_columns: tensor([  0, 142, 160, 171, 184, 205])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7806
# num_important_columns: tensor([  0, 142, 158, 159, 190, 206])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8120
# num_important_columns: tensor([  0, 142, 158, 165, 207])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7479
# num_important_columns: tensor([  0, 159, 189, 198, 208])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7658
# num_important_columns: tensor([  0, 142, 198, 209])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8287
# num_important_columns: tensor([  0, 142, 192, 210])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7267
# num_important_columns: tensor([  0, 180, 202, 211])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.6691
# num_important_columns: tensor([  0, 189, 199, 212])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8965
# num_important_columns: tensor([  0, 142, 160, 171, 184, 205, 213])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8665
# num_important_columns: tensor([  0, 142, 172, 191, 200, 214])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.8931
# num_important_columns: tensor([  0, 142, 174, 192, 210, 215])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7828
# num_important_columns: tensor([  0, 158, 159, 189, 216])
# importance_ratio (重要列中的 >0.05 元素 / 全体 >0.05 元素): 0.7758
# num_important_columns: tensor([  0, 142, 198, 208, 217])
# Average number of important columns: 4.75

# %%
super_attn = []
for i in range(32,64):
    super_attn .append( torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/real{i}.pt").to('cpu') )
super_attn = torch.stack(super_attn)
print(super_attn.shape)
# Out:
# torch.Size([32, 1, 32, 60, 218])

# %%
def super_extract_zero(super_attn_weights:torch.Tensor):
    attn_weights = super_attn_weights.view(32*32,super_attn_weights.shape[-2],super_attn_weights.shape[-1])
    iszero = attn_weights < 0.005
    zeroindex = torch.all(iszero,dim=0)
    
    print(zeroindex.shape)
    for i in np.array(zeroindex).tolist():
        print(i)
    print(zeroindex.sum(dim=-1))
        
    return zeroindex    
    # print(zeroindex.shape)
    # for i in np.array(zeroindex).tolist()[0]:
    #     print(i)
    # print(zeroindex.sum(dim=-1))
    
super_extract_zero(super_attn)
# Out:
# torch.Size([60, 218])
# [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, True, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, True, True, False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, False, False, False, True, False, False, True, True, False, False, False, False, False, True, False, False, False, False, True, False, False, True, True, False, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, True, True, True, False, False, False, False, True, True, False, False, False, False, True, True, False, True, True, True, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, True, True, False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, True, False, True, True, False, False, False, False, False, False, False, False, True, True, True, False, True, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, True, False, True, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, True, True, False, False, False, False, True, True, False, True, True, False, True, False, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, True, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, False, False, True, True, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, True, False, False, True, False, False, False, False, False, False, True, False, False, False, True, False, False, True, True, False, False, False, False, False, False, True, False, False, False, True, True, False, True, True, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, True, True, False, False, False, True, False, True, False, True, True, False, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, True, False, False, True, False, False, False, False, True, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, True, True, True, False, False, False, False, True, True, False, False, False, False, False, True, False, True, True, False, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, True, False, True, False, False, False, True, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, False, False, True, True, False, False, False, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, True, False, False, False, True, False, True, True, True, False, False, False, False, True, True, False, False, False, True, True, True, False, False, True, True, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, True, True, True, False, True, True, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, False, False, False, True, False, True, True, True, False, False, False, False, True, True, True, False, False, True, False, True, False, True, True, False, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# ...
# [False, False, True, False, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# [False, False, True, True, False, True, True, False, True, False, False, False, False, False, False, True, True, True, False, True, False, False, False, False, False, True, False, False, True, False, False, False, False, True, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, True, True, True, False, False, False, True, True, False, True, True, False, True, False, True, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True]
# [False, False, True, False, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True]
# [False, False, True, True, False, True, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True]
# [False, False, True, False, False, True, True, True, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, True, False, True, True, False, False, False, False, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, False, True, True, True, True]
# [False, False, True, False, False, True, True, False, True, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True]
# [False, True, True, True, False, True, True, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, True, False, False, True, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, True, True, True, False, False, False, False, True, True, True, False, False, True, True, True, False, True, True, True, False, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, False, True, True]
# [False, False, True, False, False, True, True, True, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, True, False, True, True, False, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, True, True, False, False, True, False, False, False, False, False, False, True, False, False, False, False, False, True, True, True, False, False, False, False, True, True, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, False, True]
# [False, False, True, False, False, True, True, True, True, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, True, False, False, True, False, False, False, False, False, False, True, True, False, False, False, False, False, False, True, True, False, False, False, False, True, True, True, False, True, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, True, True, True, False, False, False, False, True, False, True, False, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, False]
# tensor([62, 69, 67, 63, 65, 78, 71, 70, 68, 68, 85, 77, 93, 71, 76, 97, 66, 66,
#         75, 77, 88, 70, 91, 93, 68, 69, 69, 73, 84, 72, 66, 95, 98, 73, 68, 67,
#         74, 67, 95, 93, 66, 69, 69, 63, 67, 73, 67, 89, 66, 89, 66, 68, 98, 67,
#         66, 74, 85, 93, 85, 82])
# tensor([[False, False, False,  ...,  True,  True,  True],
#         [False, False,  True,  ...,  True,  True,  True],
#         [False, False,  True,  ...,  True,  True,  True],
#         ...,
#         [False,  True,  True,  ..., False,  True,  True],
#         [False, False,  True,  ...,  True, False,  True],
#         [False, False,  True,  ...,  True,  True, False]])

# %%
import torch
startlinear = 4
originarea = (startlinear+1)* 32
draftarea = (startlinear)*6
print(originarea,'->',originarea+32)

origin_attn = []
for i in range(originarea,originarea+32):
    origin_attn .append( torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/real{i}.pt").to('cpu') )
origin_attn = torch.stack(origin_attn)
print(origin_attn.shape)

draft_attn=  torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/draft{startlinear}.pt").to('cpu')
# Out:
# 160 -> 192
# torch.Size([32, 1, 32, 60, 237])

# %%
import torch
def super_extract_zero(super_attn_weights:torch.Tensor,thres=0.05):
    attn_weights = super_attn_weights.view(-1,super_attn_weights.shape[-2],super_attn_weights.shape[-1])
    iszero = attn_weights < thres
    zeroindex = torch.all(iszero,dim=0)
    
    # print(zeroindex.shape)
    # for i in np.array(zeroindex).tolist():
    #     print(i)
    # print(zeroindex.sum(dim=-1))
        
    return zeroindex   

def extract_zero(attn_weights:torch.Tensor,thres=0.05):
    iszero = attn_weights < thres
    zeroindex = torch.all(iszero,dim=1)
    # print(zeroindex.shape)
    # for i in np.array(zeroindex).tolist()[0]:
    #     print(i)
    # print(zeroindex.sum(dim=-1))
    zeroindex = zeroindex[0,:,:zeroindex.shape[2]] # 削除不share的部分
    # print(zeroindex.shape)
    return zeroindex

def get_out_percent(origin_attn,draft_attn:torch.Tensor,thres):
    # thres = 0.005
    origin_zero = super_extract_zero(origin_attn,thres)[:,:-60]
    draft_zero = extract_zero(draft_attn,thres)[:,:-60]

    # print(origin_zero.shape)
    # print(draft_zero.shape)
    # print(len(draft_zero),draft_zero[0].shape)

    yeszeros = origin_zero & draft_zero
    # print(yeszeros.shape)

    lastavg = yeszeros.sum()/60
    print('avg blank:', lastavg)
    return lastavg
    
def get_pipeline(startlinear,thres=0.01):
    originarea = (startlinear+1)* 32

    origin_attn = []
    for i in range(originarea,originarea+32):
        origin_attn .append( torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/real{i}.pt").to('cpu') )
    origin_attn = torch.stack(origin_attn)
    # print(origin_attn.shape)


    draft_attn=torch.load(f"/home/ruiyang.chen/Code/LLM/EAGLE3/eagle/checkattn/draft{startlinear}.pt").to('cpu')
    # draft_attn = torch.stack(draft_attn)
    # print(len(draft_attn),draft_attn[0].shape)
    
    print('[',originarea,'->',originarea+32,');[',startlinear,');',end=' ')
    print('length:',origin_attn.shape[-1],end=' ')
    
    return get_out_percent(origin_attn,draft_attn,thres)

allavg=[]
for i in range(0,32):
    allavg.append(get_pipeline(i))

print(sum(allavg)/len(allavg))
# Out:
# [ 32 -> 64 );[ 0 ); length: 218 avg blank: tensor(34.3333)
# [ 64 -> 96 );[ 1 ); length: 222 avg blank: tensor(34.)
# [ 96 -> 128 );[ 2 ); length: 229 avg blank: tensor(31.6000)
# [ 128 -> 160 );[ 3 ); length: 230 avg blank: tensor(32.0667)
# [ 160 -> 192 );[ 4 ); length: 237 avg blank: tensor(51.2333)
# [ 192 -> 224 );[ 5 ); length: 241 avg blank: tensor(43.5667)
# [ 224 -> 256 );[ 6 ); length: 248 avg blank: tensor(47.5000)
# [ 256 -> 288 );[ 7 ); length: 255 avg blank: tensor(52.2000)
# [ 288 -> 320 );[ 8 ); length: 262 avg blank: tensor(54.5667)
# [ 320 -> 352 );[ 9 ); length: 266 avg blank: tensor(64.2167)
# [ 352 -> 384 );[ 10 ); length: 273 avg blank: tensor(64.3000)
# [ 384 -> 416 );[ 11 ); length: 276 avg blank: tensor(61.7333)
# [ 416 -> 448 );[ 12 ); length: 283 avg blank: tensor(61.8167)
# [ 448 -> 480 );[ 13 ); length: 290 avg blank: tensor(59.1667)
# [ 480 -> 512 );[ 14 ); length: 297 avg blank: tensor(61.6833)
# [ 512 -> 544 );[ 15 ); length: 304 avg blank: tensor(75.8667)
# [ 544 -> 576 );[ 16 ); length: 308 avg blank: tensor(82.2667)
# [ 576 -> 608 );[ 17 ); length: 315 avg blank: tensor(78.9667)
# [ 608 -> 640 );[ 18 ); length: 322 avg blank: tensor(78.9667)
# [ 640 -> 672 );[ 19 ); length: 327 avg blank: tensor(95.5667)
# [ 672 -> 704 );[ 20 ); length: 329 avg blank: tensor(86.5833)
# [ 704 -> 736 );[ 21 ); length: 336 avg blank: tensor(92.3333)
# [ 736 -> 768 );[ 22 ); length: 340 avg blank: tensor(108.7833)
# [ 768 -> 800 );[ 23 ); length: 346 avg blank: tensor(102.2333)
# [ 800 -> 832 );[ 24 ); length: 347 avg blank: tensor(90.1500)
# [ 832 -> 864 );[ 25 ); length: 354 avg blank: tensor(103.1667)
# [ 864 -> 896 );[ 26 ); length: 361 avg blank: tensor(107.4333)
# [ 896 -> 928 );[ 27 ); length: 368 avg blank: tensor(116.5000)
# [ 928 -> 960 );[ 28 ); length: 372 avg blank: tensor(123.0333)
# [ 960 -> 992 );[ 29 ); length: 379 avg blank: tensor(115.0833)
# [ 992 -> 1024 );[ 30 ); length: 383 avg blank: tensor(103.6500)
# [ 1024 -> 1056 );[ 31 ); length: 389 avg blank: tensor(122.8833)
# tensor(76.1703)
